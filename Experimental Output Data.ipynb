# %%
import pandas as pd

# %%
path = "" # route to experiments folder

# %% [markdown]
# Notebook to read the datasets generated by all the experiments
#
# Author: Oscar Fernández Vicente: ofvicente@gmail.com.

# %% [markdown]
# # 1- Agents data

# %% [markdown]
# Basic data generated by all the agents involved in simulations:
#
# - DQN
# - Random
# - Persistent

# %%
names =["NUM_EXP", "iter", "last_state", "last_action", "reward", "accumreward", "lastkind", "splitted_rew", "marktovalue", "CASH","epsilon", "buyq", "sellq", "inventory", "spread"]

# %%
df = pd.read_csv(path + "/experiments/training/B05_alpha1/QL_1_REWARDS_PAPER_STATES123.bz2", names = names).dropna()

# %%
df
# Out:
#         NUM_EXP  iter                                         last_state  \
# 1             0     2  [[-7.38558201e-01 -7.76078773e-01  7.71281612e...
# 2             0     3  [[ 0.23709238  0.09854247  0.09446921  0.08006...
# 3             0     4  [[ 0.23709238  1.9352471  -0.25235172  0.10058...
# 4             0     5  [[ 1.47882947 -0.77607877  0.16383339 -0.33038...
# 5             0     6  [[-0.7385582  -0.77607877  0.16383339  0.18267...
# ...         ...   ...                                                ...
# 107963      149   716  [[-0.7385582   1.2355501  -0.28703382  0.12110...
# 107964      149   717  [[-0.7385582   1.76032285 -0.81593574 -0.38169...
# 107965      149   718  [[-0.7385582   1.14808797 -0.9048086  -0.63052...
# 107966      149   719  [[-0.7385582  -0.77607877 -0.4544833  -0.54908...
# 107967      149   720  [[-0.7385582   0.8857016  -0.38525459 -0.07722...
#
#                        last_action      reward   accumreward lastkind  \
# 1        [-0.8, -0.8, 0.0, 0.0, 1]    0.000000  0.000000e+00   random
# 2             [0, -1, 0.5, 0.0, 0]   10.000000  1.000000e+01   random
# 3          [-1, -0.4, 0.0, 1.8, 1]  185.000000  1.950000e+02   random
# 4              [0, 1, 1.0, 2.0, 0]  -37.500000  1.575000e+02   random
# 5        [-0.2, -0.2, 0.4, 0.4, 1]   17.500000  1.750000e+02   random
# ...                            ...         ...           ...      ...
# 107963   [1, -0.2, 1.0, 0.4, 0.75]  -76.890000 -1.556167e+06     best
# 107964   [1, -0.2, 1.0, 0.4, 0.75]   51.257500 -1.556116e+06     best
# 107965  [0.2, 0.4, 2.4, 2.8, 0.75]  141.375000 -1.555975e+06     best
# 107966   [1, -0.2, 2.0, 0.8, 0.75]   53.392188 -1.555921e+06     best
# 107967   [1, -0.2, 5.0, 2.0, 0.75]  -98.832031 -1.556020e+06     best
#
#                                              splitted_rew   marktovalue  \
# 1                                     [0.0, 0, 0, 0.0, 0]  9.999892e+06
# 2                                 [10.0, 0, 0.0, 27.5, 0]  1.000025e+07
# 3                                [200.0, 0, 15.0, 0.0, 0]  1.000019e+07
# 4                                 [-37.5, 0, 0.0, 0.0, 0]  1.000015e+07
# 5                                [30.0, 0, 12.5, 30.0, 0]  1.000006e+07
# ...                                                   ...           ...
# 107963                      [-54.5, 18.64, 3.75, 58.0, 0]  9.742451e+06
# 107964              [130.5625, 37.1175, 42.1875, 44.0, 0]  9.742595e+06
# 107965              [613.125, 212.0625, 259.6875, 0.0, 0]  9.742948e+06
# 107966  [248.44140625, 80.08828125, 114.9609375, 76.0, 0]  9.743509e+06
# 107967  [1307.2509765625, 1334.232421875, 71.850585937...  9.744745e+06
#
#                 CASH  epsilon  buyq  sellq   inventory  spread
# 1       9.500000e+06     0.99    55     50    0.000000     0.5
# 2       1.949788e+07     0.99    55    155    5.000000     3.0
# 3       7.500862e+06     0.99   125      0 -100.000000     1.0
# 4       7.500862e+06     0.99     0      0   25.000000     0.5
# 5       1.749803e+07     0.99     0     75    0.000000     1.0
# ...              ...      ...   ...    ...         ...     ...
# 107963  3.577995e+07     0.01     0    145 -112.500000     0.5
# 107964  3.837106e+07     0.01     0    110 -173.125000     2.0
# 107965  2.524152e+07     0.01     0      0 -153.281250     1.0
# 107966  2.322319e+07     0.01     0     95  -38.320312     2.5
# 107967  2.031727e+07     0.01     0      0 -104.580078    10.0
#
# [107818 rows x 15 columns]

# %% [markdown]
# # 2- Market data

# %% [markdown]
# Additional market data generated by the interaction of the basic agents along the simulations. Gathered and saved by every MM agent. Some info can be shared with previous dataframes.

# %%
names =["buyq","sellq","inventory","lastinventory","midprice_var","spread","lastspread","lastVolume", "mid", "bid", "ask"]

# %%
df = pd.read_csv(path + "/experiments/training/B05_alpha1/QL_1_HISTORIC_PAPER_STATES123.bz2", names=names)

# %%
df.head()
# Out:
#    buyq  sellq  inventory  lastinventory  midprice_var  spread  lastspread  \
# 0     0      0        0.0            0.0      100001.0     0.0         0.0
# 1    55     50        5.0            0.0         -21.5     0.5         0.0
# 2    55    155      -95.0            5.0          -3.5     3.0         0.5
# 3   125      0       25.0         -100.0          -2.0     1.0         3.0
# 4     0      0       25.0           25.0          -1.5     0.5         1.0
#
#    lastVolume       mid    bid    ask
# 0           0  100000.0      0      0
# 1         105   99978.5  99978  99979
# 2         210   99975.0  99972  99978
# 3         125   99973.0  99972  99974
# 4           0   99971.5  99971  99972
